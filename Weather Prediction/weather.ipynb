# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import  warnings
warnings.filterwarnings(action='ignore')

# %%
# multiclass classification
# conds -dependent feature

# %%
df=pd.read_csv('weather delhi.csv')
df
# Out:
#           datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0       19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1       19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2       19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3       19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4       19961101-16:00   Smoke      11.0      0       0           NaN   47.0
# ...                ...     ...       ...    ...     ...           ...    ...
# 100985  20170424-06:00    Haze      17.0      0       0           NaN   25.0
# 100986  20170424-09:00    Haze      14.0      0       0           NaN   16.0
# 100987  20170424-12:00    Haze      12.0      0       0           NaN   14.0
# 100988  20170424-15:00    Haze      15.0      0       0           NaN   27.0
# 100989  20170424-18:00    Haze      15.0      0       0           NaN   30.0
#
# ...

# %%
# df.describe() 
# df.info() 
# df.isnull().sum()  
# df.tail()
# df.isnull().mean()*100

# %%
df.columns
# Out:
# Index(['datetime_utc', ' _conds', ' _dewptm', ' _fog', ' _hail',
#        ' _heatindexm', ' _hum', ' _precipm', ' _pressurem', ' _rain', ' _snow',
#        ' _tempm', ' _thunder', ' _tornado', ' _vism', ' _wdird', ' _wdire',
#        ' _wgustm', ' _windchillm', ' _wspdm'],
#       dtype='object')

# %%
# df.rename(columns={'_conds':'conds'},inplace=True)
df.columns=df.columns.str.lstrip(' _')

# %%
df.columns
# Out:
# Index(['datetime_utc', 'conds', 'dewptm', 'fog', 'hail', 'heatindexm', 'hum',
#        'precipm', 'pressurem', 'rain', 'snow', 'tempm', 'thunder', 'tornado',
#        'vism', 'wdird', 'wdire', 'wgustm', 'windchillm', 'wspdm'],
#       dtype='object')

# %%
# plt.figure(figsize=(4,4))
# _=sns.countplot(df['conds'])

# %%
# df['conds'].value_counts()

# %%
# df['conds'].value_counts().head(10).plot(kind='bar')

# %%
# df['wdire'].value_counts().head(10).plot(kind='bar',color='magenta')

# %%
df['tempm'].max()
# Out:
# 90.0

# %%
df['tempm'].min()
# Out:
# 1.0

# %%
df['tempm'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4416f564b644> in <module>
# ----> 1 df['tempm'].mean()
#
# NameError: name 'df' is not defined

# %%
df['datetime_utc'].max()[0:4]
# Out:
# '2017'

# %%
df['datetime_utc'].min()[0:4]
# Out:
# '1996'

# %%
df['datetime_utc']=pd.to_datetime(df['datetime_utc'])

# %%
df['year']=df['datetime_utc'].dt.year
df['month']=df['datetime_utc'].dt.month

# %%
df.drop(['datetime_utc'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    conds  dewptm  fog  hail  heatindexm   hum  precipm  pressurem  rain  snow  \
# 0  Smoke     9.0    0     0         NaN  27.0      NaN     1010.0     0     0
# 1  Smoke    10.0    0     0         NaN  32.0      NaN    -9999.0     0     0
#
#    ...  thunder  tornado  vism  wdird  wdire wgustm  windchillm  wspdm  year  \
# 0  ...        0        0   5.0  280.0   West    NaN         NaN    7.4  1996
# 1  ...        0        0   NaN    0.0  North    NaN         NaN    NaN  1996
#
#    month
# 0     11
# 1     11
#
# [2 rows x 21 columns]

# %%
df.groupby(['year'])['month'].value_counts()
# Out:
# year  month
# 1996  12       667
#       11       611
# 1997  7        656
#       1        654
#       10       640
#               ...
# 2016  1        387
# 2017  1        637
#       3        318
#       2        256
#       4        209
# Name: month, Length: 245, dtype: int64

# %%
df.groupby(['year'])['tempm'].mean()
# eda-exploded data analysis
# Out:
# year
# 1996    16.518636
# 1997    24.444635
# 1998    24.847371
# 1999    27.335731
# 2000    23.865647
# 2001    25.582460
# 2002    26.481948
# 2003    26.176556
# 2004    26.004396
# 2005    24.712715
# 2006    25.449245
# 2007    24.800211
# 2008    24.525744
# 2009    25.355360
# 2010    25.553338
# 2011    24.966362
# 2012    25.024661
# 2013    24.679222
# 2014    25.175735
# 2015    25.141832
# 2016    27.315734
# 2017    20.204369
# Name: tempm, dtype: float64

# %%
df.groupby(['year'])['rain'].sum()
# Out:
# year
# 1996      0
# 1997    201
# 1998    141
# 1999    102
# 2000    108
# 2001    146
# 2002    144
# 2003    310
# 2004    126
# 2005    138
# 2006    100
# 2007    116
# 2008    137
# 2009     90
# 2010    137
# 2011     92
# 2012     76
# 2013     76
# 2014     79
# 2015    114
# 2016    188
# 2017     31
# Name: rain, dtype: int64

# %%
# >50% nll
df.drop(['heatindexm','precipm','wgustm','windchillm'],axis=1,inplace=True)

# %%
# df.fillna(value={'vism':df['vism'].median(),'wdird':df['wdird'].median(),'wspdm':df['wspdm'].median()},inplace=True)

# %%
# df['wdire']=df['wdire'].fillna(value=df['wdire'].value_counts().mean())

# %%
# df.dropna(inplace=True)

# %%
df.isnull().mean()*100 # df.columns
# Out:
# conds         0.071294
# dewptm        0.614912
# fog           0.000000
# hail          0.000000
# hum           0.749579
# pressurem     0.229726
# rain          0.000000
# snow          0.000000
# tempm         0.666403
# thunder       0.000000
# tornado       0.000000
# vism          4.384593
# wdird        14.610357
# wdire        14.610357
# wspdm         2.334885
# year          0.000000
# month         0.000000
# dtype: float64

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
sv_model=SVC()
sv_model.fit(x_train,y_train)

# %%
# Chech Train and Test Accuracy

# %%
# Check Confusion Matrix

# %%
# Check Classification Report

# %% [markdown]
# # KNN

# %%
from sklearn .neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_train,y_train)

# %%
# Chech Train and Test Accuracy

# %%
# Check Confusion Matrix

# %%
 # Check Classification Report
